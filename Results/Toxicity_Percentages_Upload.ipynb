# %%
import pandas as pd

# %%
df = pd.read_csv("UniTox (4).csv")

# %%
for toxicity in ["cardiotoxicity","dermatological_toxicity","hematological","infertility","liver_toxicity","ototoxicity","pulmonary_toxicity","renal_toxicity"]:
  print(len(df[df[f"{toxicity}_ternary_rating"].isin(["Most"])])/len(df))
# Out:
# 0.4611248966087676
# 0.6224152191894128
# 0.47518610421836227
# 0.20471464019851116
# 0.33126550868486354
# 0.03722084367245657
# 0.2841191066997519
# 0.2729528535980149
